# %%
import os
import pandas as pd

# %%
path = 'C:/study/crawling/Downloads'
p_list = os.listdir(path)
dt_list = [i[-13:-7] for i in p_list]

# %%
data = pd.read_excel(path+'/'+p_list[0])
data.head(1)
# Out:
#       시도  시군구   어린이집명 어린이집유형 운영현황  우편번호                        주소  \
# 0  서울특별시  종로구  이화어린이집     민간   정상  3123  서울특별시 종로구 율곡로20길 3 (충신동)
#
#           전화번호         팩스번호  보육실수  ...  정원  현원    위도     경도  통학차량운영여부  홈페이지주소  \
# 0  02-747-2686  02-747-2252     6  ...  64  61  38.0  127.0        운영     NaN
#
#          인가일자 휴지시작일자 휴지종료일자 폐지일자
# 0  2004-05-03    NaN    NaN  NaN
#
# [1 rows x 23 columns]

# %%
dic = dict()
for j in p_list:
    path = 'C:/study/crawling/Downloads'
    data = pd.read_excel(path+'/'+j)
    dic[j[-13:-7]] = data

# %%
dic.keys()
# Out:
# dict_keys(['201609', '201610', '201611', '201612', '201701', '201702', '201703', '201704', '201705', '201706', '201707', '201708', '201709', '201710', '201711', '201712', '201801', '201802', '201803', '201804', '201805', '201806', '201807', '201808', '201809', '201810', '201811', '201812', '201901', '201902', '201903', '201904', '201905', '201906', '201907', '201908', '201909', '201910', '201911', '201912', '202001', '202002', '202003', '202004', '202005', '202006', '202007', '202008'])

# %%
columns = dic['201609'].columns.to_list()
columns
# Out:
# ['시도',
#  '시군구',
#  '어린이집명',
#  '어린이집유형',
#  '운영현황',
#  '우편번호',
#  '주소',
#  '전화번호',
#  '팩스번호',
#  '보육실수',
#  '보육실면적',
#  '놀이터수',
#  '보육교직원수',
#  '정원',
#  '현원',
#  '위도',
#  '경도',
#  '통학차량운영여부',
#  '홈페이지주소',
#  '인가일자',
#  '휴지시작일자',
#  '휴지종료일자',
#  '폐지일자']

# %%
len(columns)
# Out:
# 23

# %%
dic['201609']
# Out:
#          시도  시군구       어린이집명  어린이집유형 운영현황  우편번호  \
# 0     서울특별시  종로구      이화어린이집      민간   정상  3123
# 1     서울특별시  종로구      삼청어린이집     국공립   정상  3049
# 2     서울특별시  종로구      창신어린이집  사회복지법인   정상  3105
# 3     서울특별시  종로구    아동회관어린이집     국공립   정상  3094
# 4     서울특별시  종로구      부암어린이집     국공립   정상  3019
# ...     ...  ...         ...     ...  ...   ...
# 8163  서울특별시  강동구    구립현대어린이집     국공립   정상  5236
# 8164  서울특별시  강동구    구립해든어린이집     국공립   정상  5265
# 8165  서울특별시  강동구    구립연두어린이집     국공립   정상  5342
# 8166  서울특별시  강동구  구립명일사랑어린이집     국공립   정상  5297
# 8167  서울특별시  강동구   구립초롱별어린이집     국공립   정상  5294
#
#                                              주소         전화번호           팩스번호  \
# 0                      서울특별시 종로구 율곡로20길 3 (충신동)  02-747-2686    02-747-2252
# 1                      서울특별시 종로구 삼청로7길 26 (팔판동)  02-723-0155    02-723-0155
# 2                       서울특별시 종로구 창신5길 22 (창신동)  02-743-6302    02-743-6302
# 3                  서울특별시 종로구 지봉로13길 14 아동회관어린이집  02-763-6038  050-5845-6038
# 4                       서울특별시 종로구 세검정로6다길 10-7   02-396-6226    02-396-6227
# ...                                         ...          ...            ...
# 8163     서울특별시 강동구 고덕로27길 36 관리동(암사동, 강동 현대홈타운)  02-441-8333             --
# 8164                       서울특별시 강동구 상암로21길 26   02-428-7942             --
# 8165  서울특별시 강동구 천중로44길 40 101동109호(길동, 희훈리치파크A)  02-486-0268    02-487-6345
# 8166                    서울특별시 강동구 상암로 224 9-106  02-442-1449    02-426-1449
# 8167                     서울특별시 강동구 양재대로134길 41   02-428-7977             --
#
#       보육실수  ...  정원  현원    위도     경도  통학차량운영여부  \
# 0        6  ...  64  61  38.0  127.0        운영
# 1        3  ...  32  32  38.0  127.0       미운영
# 2        4  ...  77  48  38.0  127.0        운영
# 3        6  ...  96  71  38.0  127.0       미운영
# 4        5  ...  89  80  38.0  127.0        운영
# ...    ...  ...  ..  ..   ...    ...       ...
# 8163     3  ...  22  22  38.0  127.0       미운영
# 8164     5  ...  68  49  38.0  127.0       미운영
# 8165     3  ...  19  19  38.0  127.0       미운영
# 8166     3  ...  15  10  38.0  127.0       미운영
# 8167     9  ...  68  30  38.0  127.0       미운영
#
#                                   홈페이지주소        인가일자 휴지시작일자 휴지종료일자 폐지일자
# 0                                    NaN  2004-05-03    NaN    NaN  NaN
# 1     http://cafe.naver.com/samchung1004  1999-09-01    NaN    NaN  NaN
# 2                http://changsin.ukid.kr  1978-12-01    NaN    NaN  NaN
# 3                                    NaN  1988-10-01    NaN    NaN  NaN
# 4                        www.buarm.co.kr  1998-07-29    NaN    NaN  NaN
# ...                                  ...         ...    ...    ...  ...
# 8163                                 NaN  2015-12-01    NaN    NaN  NaN
# 8164                                 NaN  2015-12-01    NaN    NaN  NaN
# 8165                                 NaN  2016-02-01    NaN    NaN  NaN
# 8166                                 NaN  2016-02-01    NaN    NaN  NaN
# 8167                                 NaN  2016-02-01    NaN    NaN  NaN
#
# [8168 rows x 23 columns]

# %%
temp = []
for j in dt_list:
    temp.append(dic[j])

# %%
df = pd.concat(temp)

# %%
df.운영현황.value_counts()
# Out:
# 정상    281358
# 폐지    119534
# 휴지      9075
# 재개      5788
# Name: 운영현황, dtype: int64

# %%
df_o =df[(df.운영현황 == '정상')|(df.운영현황 =='재개')]

# %%
df_o.to_csv('어린이집_정상운영.csv')

# %%
df.to_csv('어린이집_전체.csv')
